# %%
from langchain_community.agent_toolkits.load_tools import load_tools
from langchain_community.utilities import SearxSearchWrapper
s = SearxSearchWrapper(searx_host="http://192.168.101.104:8888")
s.run("3月伊朗战事发展")
# Out:
# 'W3Schools offers free online tutorials and references on web development languages such as HTML, CSS, JavaScript, PHP, SQL, and JQuery.\n\n新华社北京3月25日电 美国和以色列对伊朗发动的军事打击25日进入第26天。以下是最新战事速览： ——伊朗 据伊朗学生通讯社报道，对于美国方面被曝向伊朗提出停战协议，伊朗政府信息委员会主席哈兹拉蒂说，"敌人列出了他们通过攻击无法实现的愿望"。美国向伊朗提出的15个停战协议要点，是 ...\n\nMar 20, 2025 · USB 3.0 was now called USB 3.1 Gen 1 with this release. USB 3.1 Gen 2 is the new specification, which supports up to 10 Gbit/s data transfer rate.\n\n新华社巴格达3月15日电 题：六问美以伊战事走向 新华社记者李军 美国和以色列对伊朗军事行动已进入第三周。伊朗伊斯兰革命卫队15日确认发起第53 ...\n\nA world divided into progress and devastation. The link between the two sides - Offshore and Inland - is a rigorous and painstaking system called The Process...\n\n3、战事外溢以及对国际经济影响有限，不会长期持续。 伊朗对海湾国家的无厘头攻击导致自己在本地区进一步被孤立，其攻击的力度与能力正在快速衰减。 在遭受伊朗导弹和无人机袭击后，一向支持伊朗的卡塔尔对伊朗进行了反击，3月2日击落两架伊朗苏-24战机。\n\nRead our 2026 Mazda 3 review for information on ratings, pricing, specs, and features, and see how the sedan and hatchback performed in our testing.\n\n【2026年3月15日】美以与伊朗战争第16天：战事进入"决定性阶段"，双方互亮底牌 截至3月15日清晨，美以与伊朗的军事冲突已进入第16天。战事不仅没有降温，反而进入了双方各自定义的"决定性阶段"。 **一、今日最新动态** • **伊朗第51波反击**：伊朗伊斯兰革命卫队宣布发起"真实承诺-4"行动第51波 ...\n\nOne of the fastest growing shooting sports in the country right now is the action-packed multi-gun competition commonly known as "3-gun."\n\n美国国务卿马可·卢比奥昨日表示，美军对伊朗“最猛烈的打击尚未到来”。早些时候，特朗普称周六空袭是“消除德黑兰威胁的最后、最佳机会” · 自战事爆发以来，已有六名美军士兵阵亡。昨日在科威特，三架美军战机遭击落，机组人员幸存，疑似为“友军误击事件”； Published 3 weeks ago'

# %%
from deepagents import create_deep_agent
from langchain_community.agent_toolkits.load_tools import load_tools
def create_agent():
    agent = create_deep_agent(
        memory=['./prompt/AGENTS.md'],
        tools=load_tools(["searx-search-results-json"],
                    searx_host="http://192.168.101.104:8888",
                    num_results=50)
    )
    return agent

# %%
agent = create_agent()
def chat(content:str)->str:
    result = agent.invoke(
        {
            "messages": [
                {
                    "role": "user",
                    "content": content,
                }
            ]
        },
        config={"configurable": {"thread_id": "12345"}},
    )
    return result['messages'][1].content
print(chat("伊朗3月的战事发展"))
# Out:
# [{'text': '我来为您搜索伊朗3月的战事发展信息。', 'type': 'text'}, {'id': 'call_7dfe1404c5924d119a74f595', 'input': {'query': '伊朗 3月 战事 2024'}, 'name': 'searx_search_results', 'type': 'tool_use'}]
